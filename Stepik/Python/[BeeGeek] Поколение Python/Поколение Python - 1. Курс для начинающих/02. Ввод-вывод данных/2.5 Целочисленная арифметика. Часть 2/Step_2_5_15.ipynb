# %% [markdown]
# # Step 15 - Четырёхзначное число
#
# Напишите программу для нахождения цифр четырёхзначного числа.
#
# Формат входных данных: На вход программе подаётся положительное четырёхзначное целое число.
#
# Формат выходных данных: Программа должна вывести текст в соответствии с условием задачи.

# %% [markdown]
# ## test:
#
# Sample Input:
#
# 3281
#
# Sample Output:
#
# Цифра в позиции тысяч равна 3
#
# Цифра в позиции сотен равна 2
#
# Цифра в позиции десятков равна 8
#
# Цифра в позиции единиц равна 1

# %%
# 06.09.2021

abcd=int(input())
d=abcd%10
c=(abcd//10)%10
b=(abcd//100)%10
a=abcd//1000
print('Цифра в позиции тысяч равна', a)
print('Цифра в позиции сотен равна', b)
print('Цифра в позиции десятков равна', c)
print('Цифра в позиции единиц равна', d)
# Out:
# Цифра в позиции тысяч равна 3
# Цифра в позиции сотен равна 2
# Цифра в позиции десятков равна 8
# Цифра в позиции единиц равна 1

# %%
# 08.07.2022

number = int(input())
print(
    f"Цифра в позиции тысяч равна {number // 1000}",
    f"Цифра в позиции сотен равна {(number // 100) % 10}",
    f"Цифра в позиции десятков равна {(number // 10) % 10}",
    f"Цифра в позиции едениц равна {number % 10}",
    sep = "\n"
)
# Out:
# Цифра в позиции тысяч равна 3
# Цифра в позиции сотен равна 2
# Цифра в позиции десятков равна 8
# Цифра в позиции едениц равна 1
