# %% [markdown]
# # Step 13 - Трехзначное число
#
# Напишите программу, в которой рассчитывается сумма и произведение цифр положительного трёхзначного числа.
#
# Формат входных данных: На вход программе подаётся положительное трёхзначное число.
#
# Формат выходных данных: Программа должна вывести два числа с поясняющим текстом: сумма цифр и произведение цифр.

# %% [markdown]
# ## test:
#
# Sample Input:
#
# 123
#
# Sample Output:
#
# Сумма цифр = 6
#
# Произведение цифр = 6

# %%
# 06.09.2021

a=int(input())
a1=a%10
a2=(a//10)%10
a3=a//100
print('Сумма цифр =', a3+a2+a1)
print('Произведение цифр =', a3*a2*a1)
# Out:
# Сумма цифр = 6
# Произведение цифр = 6

# %%
# 07.07.2022

number = int(input())
print(
    f"Сумма цифр = {(a // 100) + ((a // 10) % 10) + (a % 10)}",
    f"Произведение цифр = {(a // 100) * ((a // 10) % 10) * (a % 10)}",
    sep = "\n"
)
# Out:
# Сумма цифр = 6
# Произведение цифр = 6
