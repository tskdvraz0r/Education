# %% [markdown]
# # Step 08 - Значение функции
#
# Напишите программу вычисления значения функции f(a,b) = 3 * (a + b) ** 3 + 275 * b ** 2 − 127 * a − 41 по введеным целым значениям a и b.
#
# Формат входных данных: На вход программе подаётся два целых числа, каждое на отдельной строке. В первой строке — значение a, во второй строке — значение b.
#
# Формат выходных данных: Программа должна вывести значение функции по введённым числам a и b.

# %% [markdown]
# ## test:
#
# Sample Input:
#
# 1
#
# 1
#
# Sample Output:
#
# 131

# %%
# 06.09.2021

a=int(input())
b=int(input())
print(3*(a+b)**3+275*b**2-127*a-41)
# Out:
# 131

# %%
# 07.07.2022

a, b = int(input()), int(input())
print(3 * (a + b) ** 3 + 275 * b ** 2 - 127 * a - 41)
# Out:
# 131
