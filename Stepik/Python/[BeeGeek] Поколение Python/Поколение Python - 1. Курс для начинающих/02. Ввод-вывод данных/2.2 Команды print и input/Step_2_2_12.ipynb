# %% [markdown]
# # Step 12 - Любимая команда
#
# На вход программе подается строка текста – название футбольной команды. Напишите программу, которая повторяет ее на экране со словами « - чемпион!» (без кавычек).
#
# Формат входных данных: На вход программе подается название футбольной команды.
#
# Формат выходных данных: Программа должна вывести текст согласно условиям задачи.

# %% [markdown]
# ## test:
#
# Sample Input:
#
# Барселона
#
# Sample Output:
#
# Барселона - чемпион!

# %%
# 05.09.2021

name= input()
print(name,'- чемпион!')
# Out:
# Барселона - чемпион!

# %%
# 07.07.2022

print(f"{input()} - чемпион!")
# Out:
# Барселона - чемпион!
