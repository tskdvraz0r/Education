# %% [markdown]
# # Step 7 - Звездный треугольник
#
# Напишите программу, которая выводит указанный треугольник, состоящий из звездочек (*).

# %%
# 05.09.2022

print('*')
print('**')
print('***')
print('****')
print('*****')
print('******')
print('*******')
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %%
# 07.07.2022

print(* (("*") * (i + 1) for i in range(7)), sep = "\n")
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
