# %% [markdown]
# # Step 02 - Python is awesome
#
# Напишите программу, которая выводит слова «Python is awesome!» (без кавычек) 10 раз.
#
# Формат входных данных:
#
# Формат выходных данных: Программа должна вывести 10 раз текст «Python is awesome!», каждый на отдельной строке

# %%
# 26.09.2021

for i in range(10):
    print('Python is awesome!')
# Out:
# Python is awesome!
# Python is awesome!
# Python is awesome!
# Python is awesome!
# Python is awesome!
# Python is awesome!
# Python is awesome!
# Python is awesome!
# Python is awesome!
# Python is awesome!
