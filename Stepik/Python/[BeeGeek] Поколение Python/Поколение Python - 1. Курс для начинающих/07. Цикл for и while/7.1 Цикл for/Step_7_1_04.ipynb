# %% [markdown]
# # Step 04 - Последовательность символов
#
# Напишите программу, которая использует ровно три цикла for для печати следующей последовательности символов:
#
# Формат выходных данных: Программа должна вывести указанную последовательность символов.

# %% [markdown]
# ## test:
#
# Sample Input:
#
# Sample Output:
#
# AAA
#
# AAA
#
# AAA
#
# AAA
#
# AAA
#
# AAA
#
# BBBB
#
# BBBB
#
# BBBB
#
# BBBB
#
# BBBB
#
# E
#
# TTTTT
#
# TTTTT
#
# TTTTT
#
# TTTTT
#
# TTTTT
#
# TTTTT
#
# TTTTT
#
# TTTTT
#
# TTTTT
#
# G

# %%
# 26.09.2021

for i in range(6):
    print('AAA')
for i in range(5):
    print('BBBB')
print('E')
for i in range(9):
    print('TTTTT')
print('G')
# Out:
# AAA
# AAA
# AAA
# AAA
# AAA
# AAA
# BBBB
# BBBB
# BBBB
# BBBB
# BBBB
# E
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# G
