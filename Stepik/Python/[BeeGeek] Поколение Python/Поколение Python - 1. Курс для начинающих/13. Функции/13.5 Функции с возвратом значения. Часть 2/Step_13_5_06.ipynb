# %% [markdown]
# # Step 06 - Ровно в одном
#
# Напишите функцию is_one_away(word1, word2), которая принимает в качестве аргументов два слова word1 и word2 и возвращает значение True если слова имеют одинаковую длину и отличаются ровно в 1 символе и False в противном случае.

# %% [markdown]
# ## test: <br/>
# Sample Input: <br/>
# bike <br/>
# hike <br/>
#
# Sample Output: <br/>
# True <br/>

# %%
# 13.11.2021

# объявление функции
def is_one_away(word1, word2):
    if len(word1) != len(word2):
        return False
    
    if len(word1) == len(word2):
        count_same = 0
        
        for i in range(len(word1)):
            if word1[i] == word2[i]:
                count_same += 1
    
    if count_same == len(word1) - 1:
        return True
    else:
        return False
            

# считываем данные
txt1 = input()
txt2 = input()

# вызываем функцию
print(is_one_away(txt1, txt2))
# Out:
# True
