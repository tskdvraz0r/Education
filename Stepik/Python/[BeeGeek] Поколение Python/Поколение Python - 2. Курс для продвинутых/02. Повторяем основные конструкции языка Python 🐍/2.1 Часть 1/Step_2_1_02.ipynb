# %% [markdown]
# # Step 02 - На easy
#
# На вход программе подаются два целых числа a и b. Напишите программу, которая выводит:
# - сумму чисел a и b;
# - разность чисел a и b;
# - произведение чисел a и b;
# - частное чисел a и b;
# - целую часть от деления числа a на b;
# - остаток от деления числа a на b;
# - корень квадратный из суммы их 10-х степеней: sqrt(a ** 10 + b ** 10).
#
# **Формат входных данных:** На вход программе подаются два целых числа a и b (b ≠ 0), каждое на отдельной строке.
#
# **Формат выходных данных:** Программа должна вывести результаты математических операций в соответствии с условием задачи.

# %% [markdown]
# ## test: <br/>
# Sample Input: <br/>
# 3 <br/>
# 8 <br/>
#
# Sample Output: <br/>
# 11 <br/>
# -5 <br/>
# 24 <br/>
# 0.375 <br/>
# 0 <br/>
# 3 <br/>
# 32768.90100384814 <br/>

# %%
# 01.04.2022

a, b = int(input()), int(input())
if b != 0:
    print(
        a + b,
        a - b,
        a * b,
        a / b,
        a // b,
        a % b,
        (a ** 10 + b ** 10) ** 0.5,
        sep = '\n'
    )
# Out:
# 11
# -5
# 24
# 0.375
# 0
# 3
# 32768.90100384814
